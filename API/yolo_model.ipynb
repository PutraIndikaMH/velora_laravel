# %%
from ultralytics import YOLO
model = YOLO('best.pt')
results = model('D:\Semester 4\API_AI_RPL\images (1).jpg')

# Check if there are any detections
has_detection = len(results[0].boxes) > 0
print(has_detection)
# Out:
# image 1/1 D:\Semester 4\API_AI_RPL\images (1).jpg: 480x640 11 jerawats, 373.5ms
# Speed: 0.0ms preprocess, 373.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# True

# %%
results[0].show()  # Display the results for the first image
# Out:
# <PIL.Image.Image image mode=RGB size=259x194>
